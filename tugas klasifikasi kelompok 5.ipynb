# %% [markdown]
# # Tugas EDA & Klasifikasi Kelompok 5_C2

# %% [markdown]
# FIKRY IDHAM DWIYANA (2101294)

# %% [markdown]
# RATU SYAHIRAH KHAIRUNNISA (2200978)

# %% [markdown]
# ADRIAN MULIANTO (2200939)

# %% [markdown]
# TALITHA FAYARINA ADHIGUNAWAN (2201271)

# %% [markdown]
# WILDAN HAFIZH RAFFIANSHAR (2202301)

# %% [markdown]
# ## Study Case : Non Performing Loan

# %% [markdown]
# Datanya adalah NPL (Non Performing Loan) untuk mendeteksi nasabah yang kreditnya akan macet (gagal bayar). Field yang menjadi kelas yang harus diprediksi adalah  "flag_kredit_macet".

# %% [markdown]
# ### Import library yang diperlukan

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Explorasi Data

# %% [markdown]
# ### Membaca Data Train

# %%
train = pd.read_csv("npl_train.txt")

# %% [markdown]
# ### Copy Data Original

# %% [markdown]
# Membuat salinan data sehingga meskipun harus membuat perubahan apa pun pada data set ini, tidak akan kehilangan data asli

# %%
train_original = train.copy()

# %% [markdown]
# ### Melihat isi data

# %%
train.head(10)
# Out:
#     X  jumlah_kartu  outstanding  limit_kredit    tagihan  \
# 0   1             2        36158     7000000.0    23437.0
# 1   2             2       268691    10000000.0   254564.0
# 2   3             3      6769149    28000000.0  4159779.0
# 3   4             4      3496732    21000000.0   111231.0
# 4   5             2      9402085    10000000.0  6099283.0
# 5   6             2      6227439    80000000.0  2081248.0
# 6   7             2      3906290     4000000.0  2043682.0
# 7   8             4      9534837    20000000.0  3692028.0
# 8   9             2      4145065     5000000.0  4021399.0
# 9  10             4      1818606     7000000.0  1765911.0
#
#    total_pemakaian_tunai  total_pemakaian_retail  sisa_tagihan_tidak_terbayar  \
# 0                    0.0                    94.0                      26323.0
# 1                    0.0                  1012.0                          0.0
# 2                    0.0                     0.0                          0.0
# 3                    0.0               2536660.0                     581334.0
# 4                    0.0               2666558.0                    5951865.0
# 5                    0.0               3690250.0                    4613435.0
# 6                    0.0                230400.0                    3314046.0
# 7                    0.0               9327612.0                    7881069.0
# 8                    0.0                335680.0                    4122425.0
# 9                    0.0                     0.0                    1627786.0
#
#   kode_cabang  rasio_pembayaran  ...  flag_kredit_macet  \
# 0           I            102.19  ...                  0
# 1           A              0.00  ...                  0
# 2           A            100.00  ...                  0
# 3           G            100.00  ...                  0
# 4           A             95.99  ...                  0
# 5           A              0.00  ...                  0
# 6           A             18.47  ...                  0
# 7           A             58.55  ...                  0
# 8           B             15.24  ...                  0
# 9           A            100.00  ...                  0
#
#    jumlah_tahun_sejak_pembukaan_kredit  total_pemakaian  \
# 0                            15.416667             94.0
# 1                             0.750000           1012.0
# 2                            10.750000              0.0
# 3                            19.750000        2536660.0
# 4                             1.666667        2666558.0
# 5                            10.250000        3690250.0
# 6                             4.666667         230400.0
# 7                             0.750000        9327612.0
# 8                             5.666667         335680.0
# 9                             8.500000              0.0
#
#    sisa_tagihan_per_jumlah_kartu  sisa_tagihan_per_limit  \
# 0                       13161.50                0.003760
# 1                           0.00                0.000000
# 2                           0.00                0.000000
# 3                      145333.50                0.027683
# 4                     2975932.50                0.595186
# 5                     2306717.50                0.057668
# 6                     1657023.00                0.828511
# 7                     1970267.25                0.394053
# 8                     2061212.50                0.824485
# 9                      406946.50                0.232541
#
#    total_pemakaian_per_limit  pemakaian_3bln_per_limit  \
# 0                   0.000013                  0.011719
# 1                   0.000101                  0.000000
# 2                   0.000000                  0.040518
# 3                   0.120793                  0.055971
# 4                   0.266656                  0.323027
# 5                   0.046128                  0.017184
# 6                   0.057600                  0.018750
# 7                   0.466381                  0.239289
# 8                   0.067136                  0.196042
# 9                   0.000000                  0.075000
#
#    pemakaian_6bln_per_limit  utilisasi_3bulan  utilisasi_6bulan
# 0                  0.017810          0.013228          0.021949
# 1                  0.000000          0.004232          0.000300
# 2                  0.047703          0.249389          0.267853
# 3                  0.016851          0.101912          0.346635
# 4                  0.131162          0.707865          0.336571
# 5                  0.117513          0.038964          0.181863
# 6                  0.166667          1.014776          0.977231
# 7                  0.241599          0.261753          0.224026
# 8                  0.000000          0.470024          0.000000
# 9                  0.094801          0.315145          0.626448
#
# [10 rows x 24 columns]

# %%
train.tail()
# Out:
#            X  jumlah_kartu  outstanding  limit_kredit     tagihan  \
# 15488  15489             2     20743090    20000000.0  20527879.0
# 15489  15490             2      3855317    17000000.0   3160704.0
# 15490  15491             2        62162     6000000.0     41120.0
# 15491  15492             3       264597     4000000.0    252864.0
# 15492  15493             2      4067271     5000000.0   3939921.0
#
#        total_pemakaian_tunai  total_pemakaian_retail  \
# 15488                    0.0                295000.0
# 15489                    0.0                269998.0
# 15490                    0.0                   238.0
# 15491                    0.0                  1018.0
# 15492                    0.0                     0.0
#
#        sisa_tagihan_tidak_terbayar kode_cabang  rasio_pembayaran  ...  \
# 15488                   14769911.0           A               0.0  ...
# 15489                          0.0           A             100.0  ...
# 15490                          0.0           A             100.0  ...
# 15491                     246512.0           I             102.0  ...
# 15492                    4062413.0           F              95.7  ...
#
#        flag_kredit_macet  jumlah_tahun_sejak_pembukaan_kredit  \
# 15488                  0                                 1.00
# 15489                  0                                 9.33
# 15490                  0                                 2.00
# 15491                  0                                 3.83
# 15492                  0                                 2.25
#
#        total_pemakaian  sisa_tagihan_per_jumlah_kartu  sisa_tagihan_per_limit  \
# 15488         295000.0                      7384956.0                  0.7380
# 15489         269998.0                            0.0                  0.0000
# 15490            238.0                            0.0                  0.0000
# 15491           1018.0                        82171.0                  0.0616
# 15492              0.0                      2031207.0                  0.8120
#
#        total_pemakaian_per_limit  pemakaian_3bln_per_limit  \
# 15488                   0.014700                    0.0581
# 15489                   0.015900                    0.1370
# 15490                   0.000040                    0.0000
# 15491                   0.000255                    0.0000
# 15492                   0.000000                    0.2500
#
#        pemakaian_6bln_per_limit  utilisasi_3bulan  utilisasi_6bulan
# 15488                    0.0262            1.0200             1.010
# 15489                    0.0737            0.2110             0.160
# 15490                    0.3360            0.0104             0.113
# 15491                    0.2680            0.3270             0.647
# 15492                    0.3330            1.0600             1.050
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15493 entries, 0 to 15492
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   X                                    15493 non-null  int64
#  1   jumlah_kartu                         15493 non-null  int64
#  2   outstanding                          15493 non-null  int64
#  3   limit_kredit                         15493 non-null  float64
#  4   tagihan                              15493 non-null  float64
#  5   total_pemakaian_tunai                15493 non-null  float64
#  6   total_pemakaian_retail               15493 non-null  float64
#  7   sisa_tagihan_tidak_terbayar          15493 non-null  float64
#  8   kode_cabang                          15393 non-null  object
#  9   rasio_pembayaran                     15493 non-null  float64
#  10  persentasi_overlimit                 15493 non-null  float64
#  11  rasio_pembayaran_3bulan              15493 non-null  float64
#  12  rasio_pembayaran_6bulan              15493 non-null  float64
#  13  skor_delikuensi                      15493 non-null  int64
#  14  flag_kredit_macet                    15493 non-null  int64
#  15  jumlah_tahun_sejak_pembukaan_kredit  15493 non-null  float64
#  16  total_pemakaian                      15493 non-null  float64
#  17  sisa_tagihan_per_jumlah_kartu        15493 non-null  float64
#  18  sisa_tagihan_per_limit               15493 non-null  float64
#  19  total_pemakaian_per_limit            15493 non-null  float64
#  20  pemakaian_3bln_per_limit             15493 non-null  float64
#  21  pemakaian_6bln_per_limit             15493 non-null  float64
#  22  utilisasi_3bulan                     15493 non-null  float64
#  23  utilisasi_6bulan                     15493 non-null  float64
# dtypes: float64(18), int64(5), object(1)
# memory usage: 2.8+ MB

# %%
train.columns
# Out:
# Index(['X', 'jumlah_kartu', 'outstanding', 'limit_kredit', 'tagihan',
#        'total_pemakaian_tunai', 'total_pemakaian_retail',
#        'sisa_tagihan_tidak_terbayar', 'kode_cabang', 'rasio_pembayaran',
#        'persentasi_overlimit', 'rasio_pembayaran_3bulan',
#        'rasio_pembayaran_6bulan', 'skor_delikuensi', 'flag_kredit_macet',
#        'jumlah_tahun_sejak_pembukaan_kredit', 'total_pemakaian',
#        'sisa_tagihan_per_jumlah_kartu', 'sisa_tagihan_per_limit',
#        'total_pemakaian_per_limit', 'pemakaian_3bln_per_limit',
#        'pemakaian_6bln_per_limit', 'utilisasi_3bulan', 'utilisasi_6bulan'],
#       dtype='object')

# %%
train.shape
# Out:
# (15493, 24)

# %% [markdown]
# ### Target Variable

# %% [markdown]
# target pada data set ini adalah flag_kredit_macet

# %%
print(train["flag_kredit_macet"].count())
train["flag_kredit_macet"].value_counts()
# Out:
# 15493
# 0    14134
# 1     1359
# Name: flag_kredit_macet, dtype: int64

# %%
print(train["skor_delikuensi"].count())
train["skor_delikuensi"].value_counts()
# Out:
# 15493
# 0    15451
# 1       29
# 2        4
# 4        4
# 5        3
# 3        2
# Name: skor_delikuensi, dtype: int64

# %% [markdown]
# ### Menghitung Jumlah Setiap Nilai dalam Kolom "flag_kredit_macet"

# %%
# Menghitung jumlah setiap nilai dalam kolom "flag_kredit_macet"
flag_kredit_macet_counts = train['flag_kredit_macet'].value_counts()

# Membuat pie chart
plt.pie(flag_kredit_macet_counts, labels=flag_kredit_macet_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen'])
plt.title('Distribusi flag_kredit_macet')
plt.show()

# %%
print(train["rasio_pembayaran"].count())
train["rasio_pembayaran"].value_counts()
# Out:
# 15493
# 0.00      4740
# 100.00    4017
# 10.00      207
# 101.00     196
# 99.90      107
#           ...
# 40.09        1
# 9.04         1
# 16.24        1
# 11.23        1
# 16.74        1
# Name: rasio_pembayaran, Length: 1665, dtype: int64

# %%
print(train["skor_delikuensi"].count())
train["skor_delikuensi"].value_counts()
# Out:
# 15493
# 0    15451
# 1       29
# 2        4
# 4        4
# 5        3
# 3        2
# Name: skor_delikuensi, dtype: int64

# %%
print(train["limit_kredit"].count())
train["limit_kredit"].value_counts()
# Out:
# 15493
# 3000000.0      2183
# 5000000.0      2131
# 7000000.0      1118
# 10000000.0      959
# 20000000.0      949
#                ...
# 105000000.0       1
# 122000000.0       1
# 123000000.0       1
# 107000000.0       1
# 205000000.0       1
# Name: limit_kredit, Length: 150, dtype: int64

# %%
print(train["utilisasi_3bulan"].count())
train["utilisasi_3bulan"].value_counts()
# Out:
# 15493
# 1.010000    158
# 1.030000    158
# 1.020000    155
# 1.060000    146
# 1.070000    137
#            ...
# 0.108786      1
# 0.587754      1
# 0.319451      1
# 0.920002      1
# 0.058000      1
# Name: utilisasi_3bulan, Length: 4094, dtype: int64

# %% [markdown]
# ### Menampilkan Data yang memiliki NaN

# %%
# Menampilkan data yang memiliki NaN
result_nan = train[train['kode_cabang'].isna()]

#result_nan
sorted_data_nan = result_nan.sort_values(by='limit_kredit', ascending=False)
sorted_data_nan
# Out:
#            X  jumlah_kartu  outstanding  limit_kredit     tagihan  \
# 14615  14616             2     48201900   100000000.0  38470769.0
# 7440    7441             6     41331234   100000000.0  21000000.0
# 3338    3339             5     81501285   100000000.0  12438988.0
# 6442    6443             7     37922655    99000000.0   8283601.0
# 4112    4113             6     35113217    93000000.0   3146111.0
# ...      ...           ...          ...           ...         ...
# 7759    7760             2      2937936     3000000.0   3116935.0
# 8294    8295             4      3053352     3000000.0   3162419.0
# 9030    9031             2       138616     3000000.0     99963.0
# 9087    9088             2      2316350     3000000.0   3239830.0
# 15376  15377             3      2447580     3000000.0   2367565.0
#
#        total_pemakaian_tunai  total_pemakaian_retail  \
# 14615                    0.0              12600000.0
# 7440                     0.0              53000000.0
# 3338                     0.0               6189000.0
# 6442                     0.0              14154763.0
# 4112                     0.0               5882907.0
# ...                      ...                     ...
# 7759                     0.0                 50000.0
# 8294                     0.0                229800.0
# 9030                     0.0                     0.0
# 9087                     0.0                 12000.0
# 15376                    0.0                  9740.0
#
#        sisa_tagihan_tidak_terbayar kode_cabang  rasio_pembayaran  ...  \
# 14615                   40446335.0         NaN               0.0  ...
# 7440                           0.0         NaN             236.0  ...
# 3338                    70519310.0         NaN             100.0  ...
# 6442                           0.0         NaN             100.0  ...
# 4112                           0.0         NaN             100.0  ...
# ...                            ...         ...               ...  ...
# 7759                     2558147.0         NaN              19.4  ...
# 8294                     3136960.0         NaN               0.0  ...
# 9030                       87661.0         NaN             100.0  ...
# 9087                     2288782.0         NaN               0.0  ...
# 15376                    2458532.0         NaN              99.8  ...
#
#        flag_kredit_macet  jumlah_tahun_sejak_pembukaan_kredit  \
# 14615                  0                                 4.58
# 7440                   0                                 5.58
# 3338                   0                                 8.58
# 6442                   0                                 6.67
# 4112                   0                                 5.25
# ...                  ...                                  ...
# 7759                   0                                 1.67
# 8294                   0                                 4.92
# 9030                   0                                 4.75
# 9087                   0                                 7.17
# 15376                  0                                 6.58
#
#        total_pemakaian  sisa_tagihan_per_jumlah_kartu  sisa_tagihan_per_limit  \
# 14615       12600000.0                     20223168.0                  0.4040
# 7440        53000000.0                            0.0                  0.0000
# 3338         6189000.0                     14103862.0                  0.7050
# 6442        14154763.0                            0.0                  0.0000
# 4112         5882907.0                            0.0                  0.0000
# ...                ...                            ...                     ...
# 7759           50000.0                      1279074.0                  0.8530
# 8294          229800.0                       784240.0                  1.0500
# 9030               0.0                        43831.0                  0.0292
# 9087           12000.0                      1144391.0                  0.7630
# 15376           9740.0                       819511.0                  0.8200
#
#        total_pemakaian_per_limit  pemakaian_3bln_per_limit  \
# 14615                    0.12600                   0.12000
# 7440                     0.53000                   0.26700
# 3338                     0.06190                   0.00597
# 6442                     0.14300                   0.25900
# 4112                     0.06330                   0.07610
# ...                          ...                       ...
# 7759                     0.01670                   0.25900
# 8294                     0.07660                   0.29500
# 9030                     0.00000                   0.05320
# 9087                     0.00400                   0.46200
# 15376                    0.00325                   0.40500
#
#        pemakaian_6bln_per_limit  utilisasi_3bulan  utilisasi_6bulan
# 14615                   0.04550            0.2580             0.201
# 7440                    0.38600            0.4550             0.475
# 3338                    0.00174            0.7780             0.807
# 6442                    0.30300            0.3340             0.170
# 4112                    0.14600            0.4910             0.134
# ...                         ...               ...               ...
# 7759                    0.12300            0.5700             0.362
# 8294                    0.38900            0.9400             0.516
# 9030                    0.29100            0.0143             0.455
# 9087                    0.54400            1.3600             1.540
# 15376                   0.40400            0.7700             0.745
#
# [100 rows x 24 columns]

# %% [markdown]
# ### Menampilkan Baris dengan "kode_cabang" A

# %%
# Menampilkan baris dengan 'kode_cabang' sama dengan 'A'
result = train[train['kode_cabang'] == 'A']

sorted_data = result.sort_values(by='limit_kredit', ascending=False)
sorted_data
# Out:
#            X  jumlah_kartu  outstanding  limit_kredit      tagihan  \
# 13235  13236             5    443768160  1.000000e+09  628000000.0
# 9596    9597             7    631055450  1.000000e+09  186000000.0
# 8210    8211             4    798058574  5.000000e+08  382000000.0
# 12303  12304             7    631055450  3.500000e+08  419000000.0
# 7000    7001             5    443768160  3.500000e+08  419000000.0
# ...      ...           ...          ...           ...          ...
# 12973  12974             2      2569033  3.000000e+06    2178300.0
# 5824    5825             2      1942881  3.000000e+06    1884207.0
# 849      850             2      1927073  3.000000e+06    1472140.0
# 856      857             2      2443664  3.000000e+06     648793.0
# 10632  10633             2      2934115  3.000000e+06    2934115.0
#
#        total_pemakaian_tunai  total_pemakaian_retail  \
# 13235                    0.0                100000.0
# 9596                     0.0              32169795.0
# 8210                     0.0              32169795.0
# 12303             28733412.0             285000000.0
# 7000                     0.0              32169795.0
# ...                      ...                     ...
# 12973                    0.0               1027858.0
# 5824                     0.0                     0.0
# 849                      0.0                     0.0
# 856                      0.0                     0.0
# 10632                    0.0                549780.0
#
#        sisa_tagihan_tidak_terbayar kode_cabang  rasio_pembayaran  ...  \
# 13235                  223000000.0           A               0.0  ...
# 9596                           0.0           A             100.0  ...
# 8210                   444000000.0           A               0.0  ...
# 12303                  443000000.0           A              61.2  ...
# 7000                   444000000.0           A              22.8  ...
# ...                            ...         ...               ...  ...
# 12973                    2561138.0           A              50.6  ...
# 5824                     2000000.0           A              10.0  ...
# 849                      1934158.0           A             100.0  ...
# 856                      2369761.0           A             100.0  ...
# 10632                    2940769.0           A              13.2  ...
#
#        flag_kredit_macet  jumlah_tahun_sejak_pembukaan_kredit  \
# 13235                  1                             7.170000
# 9596                   1                            12.800000
# 8210                   1                            12.000000
# 12303                  0                             5.500000
# 7000                   0                             9.170000
# ...                  ...                                  ...
# 12973                  0                             7.670000
# 5824                   0                             4.420000
# 849                    0                             4.500000
# 856                    0                             0.833333
# 10632                  0                             2.920000
#
#        total_pemakaian  sisa_tagihan_per_jumlah_kartu  sisa_tagihan_per_limit  \
# 13235         100000.0                     44579953.0                0.223000
# 9596        32169795.0                            0.0                0.000000
# 8210        32169795.0                    111000000.0                0.888000
# 12303      314000000.0                     63237084.0                1.260000
# 7000        32169795.0                     88753632.0                1.270000
# ...                ...                            ...                     ...
# 12973        1027858.0                      1280569.0                0.854000
# 5824               0.0                       997711.0                0.665000
# 849                0.0                       967079.0                0.644719
# 856                0.0                      1184880.5                0.789920
# 10632         549780.0                      1470385.0                0.980000
#
#        total_pemakaian_per_limit  pemakaian_3bln_per_limit  \
# 13235                     0.0001                  0.127000
# 9596                      0.0322                  0.172000
# 8210                      0.0643                  0.255000
# 12303                     0.8960                  0.218000
# 7000                      0.0919                  0.364000
# ...                          ...                       ...
# 12973                     0.3430                  0.348000
# 5824                      0.0000                  0.228000
# 849                       0.0000                  0.287583
# 856                       0.0000                  0.266583
# 10632                     0.1830                  0.141000
#
#        pemakaian_6bln_per_limit  utilisasi_3bulan  utilisasi_6bulan
# 13235                  0.498000          0.548000          0.327000
# 9596                   0.857000          0.576000          0.341000
# 8210                   0.429000          1.100000          0.681000
# 12303                  0.156000          1.650000          0.478000
# 7000                   0.092700          1.650000          0.485000
# ...                         ...               ...               ...
# 12973                  0.104000          0.760000          1.080000
# 5824                   0.161000          0.595000          0.152000
# 849                    0.363026          0.526927          0.200441
# 856                    0.062133          0.842992          0.067017
# 10632                  0.000000          0.807000          0.626000
#
# [8705 rows x 24 columns]

# %% [markdown]
# ### Menampilkan Rata-rata Limit Kredit per Kode Cabang

# %%
# Mengelompokkan berdasarkan 'kode_cabang' dan menghitung rata-rata limit kredit
rata_rata_limit = train.groupby('kode_cabang')['limit_kredit'].mean().reset_index()

# Membuat plot batang dari rata-rata limit kredit
plt.figure(figsize=(8, 6))
sns.barplot(data=rata_rata_limit, x='kode_cabang', y='limit_kredit')
plt.title('Rata-rata Limit Kredit per Kode Cabang')
plt.xlabel('Kode Cabang')
plt.ylabel('Rata-rata Limit Kredit')
plt.show()

# %% [markdown]
# Plot ini menunjukan rata-rata limit kredit per kode cabang dan rata-rata limit yang paling tinggi adalah kode cabang A.

# %%
result.shape
# Out:
# (8705, 24)

# %% [markdown]
# ### Menampilkan Frekuensi Kode Cabang

# %%
# Menghitung frekuensi masing-masing kode cabang
kode_cabang_counts = train['kode_cabang'].value_counts()

# Membuat plot batang dari frekuensi kode cabang dengan data NaN
plt.bar(kode_cabang_counts.index, kode_cabang_counts)
plt.title('Plot Kode Cabang')
plt.xlabel('Kode Cabang')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Plot ini menunjukan frekuensi kode cabang dan kode cabang A memiliki frekuensi paling besar.

# %%
train['kode_cabang'].unique()
# Out:
# array(['I', 'A', 'G', 'B', 'E', 'K', 'F', 'C', 'J', 'H', nan, 'D'],
#       dtype=object)

# %% [markdown]
# ### Menampilkan Perbandingan Rata-rata Limit Kredit berdasarkan Kode Cabang

# %%
# Buat bar plot rata-rata limit kredit berdasarkan kode cabang
plt.figure(figsize=(8, 6))
sns.barplot(x='kode_cabang', y='limit_kredit', data=train, ci=None)
plt.title('Perbandingan Rata-rata Limit Kredit berdasarkan Kode Cabang')
plt.show()

# %% [markdown]
# Plot tersebut menunjukkan perbandingan rata-rata limit kredit berdasarkan kode cabang.

# %% [markdown]
# ### Heatmap Hubungan Antar Kolom

# %%
matrix = train.corr()
f, ax = plt.subplots(figsize=(10, 12))
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu",annot=True);

# %% [markdown]
# Heatmap tersebut menjelaskan hubungan antar kolom

# %% [markdown]
# ### Boxplot kredit_macet dengan jumlah_kartu, outstanding, limit_kredit, dan tagihan

# %%
numeric_columns = ['jumlah_kartu','outstanding', 'limit_kredit', 'tagihan']

fig, axes = plt.subplots(1, len(numeric_columns), figsize=(17, 5))
for idx, cat_col in enumerate(numeric_columns):
    sns.boxplot(y=cat_col, data=train, x='flag_kredit_macet', ax=axes[idx])
    axes[idx].set_title(f'Kredit macet by {cat_col}')
    axes[idx].set_xlabel('Flag kredit')
    axes[idx].set_ylabel(cat_col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Pada plot tersebut dapat dilihat terdapat banyak outlier.

# %% [markdown]
# ### Pairplot

# %% [markdown]
# Melihat hubungan jumlah kartu, outstanding, limit kredit, tagihan dengan flag kredit macet

# %%
df_pair = train[['jumlah_kartu','outstanding', 'limit_kredit', 'tagihan', 'flag_kredit_macet']]
sns.pairplot(df_pair, hue="flag_kredit_macet")

# %% [markdown]
# Melihat hubungan total pemakaian, rasio pembayaran, presentasi overlimit, skor delikuensi, sisa tagihan tidak dibayar dengan flag kredit macet

# %%
df_pair = train[['flag_kredit_macet','total_pemakaian', 'rasio_pembayaran', 'persentasi_overlimit', 'skor_delikuensi', 'sisa_tagihan_tidak_terbayar']]
sns.pairplot(df_pair, hue="flag_kredit_macet")

# %% [markdown]
# ### Heatmap dari tabel silang - flag_kredit_macet berdasarkan kode_cabang

# %%
# Membuat heatmap dari tabel silang
crosstab_result = pd.crosstab(train['kode_cabang'], train['flag_kredit_macet'])
sns.heatmap(crosstab_result, annot=True, cmap='coolwarm', fmt='d')
plt.title('flag kredit macet by kode cabang')
plt.show()

# %% [markdown]
# ## Training - Testing

# %% [markdown]
# Melihat hasil training - testing sebelum praproses dilakukan

# %%
# pip install xgboost

# %% [markdown]
# Sebelum training - testing lakukan encoding untuk target agar hasilnya antara 0 dan 1, pisahkan kolom target dari fitur (target dtampung dalam y, sedangkan train tanpa target ditampung dalam X), onehot data X untuk data kategori, terakhir membagi data train dan test

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# encoding
label_encoder = LabelEncoder()
train['flag_kredit_macet'] = label_encoder.fit_transform(train['flag_kredit_macet'])
list(label_encoder.classes_)

# Pisahkan kolom target (label) dari fitur
X = train.drop('flag_kredit_macet', axis=1) 
y = train[['flag_kredit_macet']]

# onehot
X = pd.get_dummies(X)

# membagi data train dan data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Melakukan training - testing dengan XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
xgb_model = XGBClassifier(n_estimators=40,max_depth=27, gamma=0.6)
xgb_model.fit(X_train,y_train)
pred_xgb=xgb_model.predict(X_test)
score_xgb = accuracy_score(pred_xgb,y_test)*100
print("Akurasi : ", score_xgb)
print(classification_report(y_test, pred_xgb))
# Out:
# Akurasi :  90.9970958373669
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      2821
#            1       0.49      0.14      0.22       278
#
#     accuracy                           0.91      3099
#    macro avg       0.71      0.56      0.59      3099
# weighted avg       0.88      0.91      0.89      3099

# %% [markdown]
# Hasil training - testing 90,99%

# %% [markdown]
# ## Praproses

# %% [markdown]
# Melakukan Praproses data untuk melihat pengaruhnya terhadap hasil training - testing

# %% [markdown]
# ### Missing Value Imputation

# %% [markdown]
# Menghilangkan nilai NULL

# %%
train.isna().sum()
# Out:
# X                                        0
# jumlah_kartu                             0
# outstanding                              0
# limit_kredit                             0
# tagihan                                  0
# total_pemakaian_tunai                    0
# total_pemakaian_retail                   0
# sisa_tagihan_tidak_terbayar              0
# kode_cabang                            100
# rasio_pembayaran                         0
# persentasi_overlimit                     0
# rasio_pembayaran_3bulan                  0
# rasio_pembayaran_6bulan                  0
# skor_delikuensi                          0
# flag_kredit_macet                        0
# jumlah_tahun_sejak_pembukaan_kredit      0
# total_pemakaian                          0
# sisa_tagihan_per_jumlah_kartu            0
# sisa_tagihan_per_limit                   0
# total_pemakaian_per_limit                0
# pemakaian_3bln_per_limit                 0
# pemakaian_6bln_per_limit                 0
# utilisasi_3bulan                         0
# utilisasi_6bulan                         0
# dtype: int64

# %% [markdown]
# Menangani nilai yang hilang pada kode_cabang dengan modus

# %%
train["kode_cabang"].fillna(train["kode_cabang"].mode()[0],inplace=True)

# %%
train.isna().sum()
# Out:
# X                                      0
# jumlah_kartu                           0
# outstanding                            0
# limit_kredit                           0
# tagihan                                0
# total_pemakaian_tunai                  0
# total_pemakaian_retail                 0
# sisa_tagihan_tidak_terbayar            0
# kode_cabang                            0
# rasio_pembayaran                       0
# persentasi_overlimit                   0
# rasio_pembayaran_3bulan                0
# rasio_pembayaran_6bulan                0
# skor_delikuensi                        0
# flag_kredit_macet                      0
# jumlah_tahun_sejak_pembukaan_kredit    0
# total_pemakaian                        0
# sisa_tagihan_per_jumlah_kartu          0
# sisa_tagihan_per_limit                 0
# total_pemakaian_per_limit              0
# pemakaian_3bln_per_limit               0
# pemakaian_6bln_per_limit               0
# utilisasi_3bulan                       0
# utilisasi_6bulan                       0
# dtype: int64

# %% [markdown]
# Sudah tidak ada data dengan nilai NULL

# %% [markdown]
# Mendrop X karena dirasa tidak berpengaruh terhadap training

# %%
train = train.drop('X', axis=1)

# %% [markdown]
# ## Training - Testing

# %% [markdown]
# Kembali melakukan training - testing untuk melihat perbedaan antara sebelum praproses dan setelah praproses

# %% [markdown]
# Seperti sebelumnya, lakukan encoding, pisahkan kolom target, onehot lalu bagi data train dan data test

# %%
# encoding
label_encoder = LabelEncoder()
train['flag_kredit_macet'] = label_encoder.fit_transform(train['flag_kredit_macet'])
list(label_encoder.classes_)

# Pisahkan kolom target (label) dari fitur
X = train.drop('flag_kredit_macet', axis=1) 
y = train[['flag_kredit_macet']]

# onehot
X = pd.get_dummies(X)

# membagi data train dan data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Mengecek apakah kolom 'X' sudah ter drop

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12394 entries, 10621 to 13349
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   jumlah_kartu                         12394 non-null  int64
#  1   outstanding                          12394 non-null  int64
#  2   limit_kredit                         12394 non-null  float64
#  3   tagihan                              12394 non-null  float64
#  4   total_pemakaian_tunai                12394 non-null  float64
#  5   total_pemakaian_retail               12394 non-null  float64
#  6   sisa_tagihan_tidak_terbayar          12394 non-null  float64
#  7   rasio_pembayaran                     12394 non-null  float64
#  8   persentasi_overlimit                 12394 non-null  float64
#  9   rasio_pembayaran_3bulan              12394 non-null  float64
#  10  rasio_pembayaran_6bulan              12394 non-null  float64
#  11  skor_delikuensi                      12394 non-null  int64
#  12  jumlah_tahun_sejak_pembukaan_kredit  12394 non-null  float64
#  13  total_pemakaian                      12394 non-null  float64
#  14  sisa_tagihan_per_jumlah_kartu        12394 non-null  float64
#  15  sisa_tagihan_per_limit               12394 non-null  float64
#  16  total_pemakaian_per_limit            12394 non-null  float64
#  17  pemakaian_3bln_per_limit             12394 non-null  float64
#  18  pemakaian_6bln_per_limit             12394 non-null  float64
#  19  utilisasi_3bulan                     12394 non-null  float64
#  20  utilisasi_6bulan                     12394 non-null  float64
#  21  kode_cabang_A                        12394 non-null  uint8
#  22  kode_cabang_B                        12394 non-null  uint8
#  23  kode_cabang_C                        12394 non-null  uint8
#  24  kode_cabang_D                        12394 non-null  uint8
#  25  kode_cabang_E                        12394 non-null  uint8
#  26  kode_cabang_F                        12394 non-null  uint8
#  27  kode_cabang_G                        12394 non-null  uint8
#  28  kode_cabang_H                        12394 non-null  uint8
#  29  kode_cabang_I                        12394 non-null  uint8
#  30  kode_cabang_J                        12394 non-null  uint8
#  31  kode_cabang_K                        12394 non-null  uint8
# dtypes: float64(18), int64(3), uint8(11)
# memory usage: 2.2 MB

# %% [markdown]
# Lakukan training - testing dengan XGBoost kembali

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
xgb_model = XGBClassifier(n_estimators=40,max_depth=27, gamma=0.6)
xgb_model.fit(X_train,y_train)
pred_xgb=xgb_model.predict(X_test)
score_xgb = accuracy_score(pred_xgb,y_test)*100
print("Akurasi : ", score_xgb)
print(classification_report(y_test, pred_xgb))
# Out:
# Akurasi :  90.57760567925138
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      2821
#            1       0.43      0.15      0.22       278
#
#     accuracy                           0.91      3099
#    macro avg       0.67      0.57      0.59      3099
# weighted avg       0.88      0.91      0.88      3099

# %% [markdown]
# Hasil training - testing adalah 90,57%

# %% [markdown]
# ### Mengembalikan nilai train

# %% [markdown]
# Dikarenakan hasil training - testing sebelum praproses lebih besar dari setelah praproses maka train dikembalikan ke kondisi semula saat sebelum praproses

# %%
train = train_original

# %% [markdown]
# ### Penanganan data Imbalance

# %% [markdown]
# Akan dilakukan metode resampling untuk menaikan jumlah data minoritas menggunakan RandomOverSampler karena terdapat ketimpangan antara dana y_train dengan X_train

# %% [markdown]
# Sebelum resempling, karena sebelumnya train diubah maka lakukan lagi pemisahan data train dan test

# %%
# encoding
label_encoder = LabelEncoder()
train['flag_kredit_macet'] = label_encoder.fit_transform(train['flag_kredit_macet'])
list(label_encoder.classes_)

# Pisahkan kolom target (label) dari fitur
X = train.drop('flag_kredit_macet', axis=1) 
y = train[['flag_kredit_macet']]

# onehot
X = pd.get_dummies(X)

# membagi data train dan data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#pip install imbalanced-learn

# %% [markdown]
# Melihat jumlah baris kolom X dan y sebelum resampling

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (12394, 1)
# (12394, 33)

# %% [markdown]
# Melihat distribusi penyebaran 0 dan 1 di y_train

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
y_train.value_counts().plot.pie(autopct='%1.1f%%')
centre=plt.Circle((0,0),0.7,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre)

# %% [markdown]
# Lakukan Resampling

# %%
from imblearn.over_sampling import RandomOverSampler
over=RandomOverSampler()
X_train,y_train=over.fit_resample(X_train, y_train)

# %% [markdown]
# Melihat jumlah baris kolom X dan y setelah resampling

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (22626, 1)
# (22626, 33)

# %% [markdown]
# shape dari X dan y telah bertambah

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
y_train.value_counts().plot.pie(autopct='%1.1f%%')
centre=plt.Circle((0,0),0.7,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre)

# %% [markdown]
# Penyebaran 0 dan 1 telah sama

# %% [markdown]
# ## Training - Testing

# %% [markdown]
# Melakukan training - testing setelah penanganan data imbalance enggunakan XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
xgb_model = XGBClassifier(n_estimators=50,max_depth=10, gamma=0.5)
xgb_model.fit(X_train,y_train)
pred_xgb=xgb_model.predict(X_test)
score_xgb = accuracy_score(pred_xgb,y_test)*100
print("Akurasi : ", score_xgb)
print(classification_report(y_test, pred_xgb))
# Out:
# Akurasi :  89.73862536302033
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      2821
#            1       0.41      0.33      0.36       278
#
#     accuracy                           0.90      3099
#    macro avg       0.67      0.64      0.65      3099
# weighted avg       0.89      0.90      0.89      3099

# %% [markdown]
# Hasil training - testing adalah 89%

# %% [markdown]
# ### Training - Testing Akhir

# %% [markdown]
# Karena hasil training - testing setelah resampling hasilnya lebih kecil daripada sebelum resampling, maka train dikembalikan lagi seperti semula

# %%
train = train_original

# %% [markdown]
# kembali melakukan encoding, onehot dan pemisahan train dan test

# %%
# encoding
label_encoder = LabelEncoder()
train['flag_kredit_macet'] = label_encoder.fit_transform(train['flag_kredit_macet'])
list(label_encoder.classes_)

# Pisahkan kolom target (label) dari fitur
X = train.drop('flag_kredit_macet', axis=1) 
y = train[['flag_kredit_macet']]

# onehot
X = pd.get_dummies(X)

# membagi data train dan data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Melakukan training - testing

# %% [markdown]
# Dengan XGboost dan Random Forest, juga melakukan perubahan HyperParameter untuk meningkatkan akurasi

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
xgb_model = XGBClassifier(n_estimators=70,max_depth=10, gamma=0.6)
xgb_model.fit(X_train,y_train)
pred_xgb=xgb_model.predict(X_test)
score_xgb = accuracy_score(pred_xgb,y_test)*100
print("Akurasi : ", score_xgb)
print(classification_report(y_test, pred_xgb))
# Out:
# Akurasi :  91.4811229428848
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      2821
#            1       0.59      0.17      0.27       278
#
#     accuracy                           0.91      3099
#    macro avg       0.75      0.58      0.61      3099
# weighted avg       0.89      0.91      0.89      3099

# %% [markdown]
# Hasil training-testing akhir adalah 91.48%

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# Melihat urutan 'importance' dari data train

# %%
feature_importances = pd.DataFrame(xgb_model.feature_importances_,index = X_train.columns, columns=['importance']).sort_values('importance',ascending=False)

print(feature_importances)
# Out:
#                                      importance
# rasio_pembayaran                       0.142277
# total_pemakaian_retail                 0.071481
# total_pemakaian_per_limit              0.061216
# persentasi_overlimit                   0.044098
# sisa_tagihan_tidak_terbayar            0.042819
# rasio_pembayaran_3bulan                0.035023
# kode_cabang_F                          0.032577
# tagihan                                0.031090
# pemakaian_3bln_per_limit               0.030833
# outstanding                            0.029214
# sisa_tagihan_per_jumlah_kartu          0.028880
# kode_cabang_E                          0.027749
# rasio_pembayaran_6bulan                0.027335
# pemakaian_6bln_per_limit               0.027064
# sisa_tagihan_per_limit                 0.025968
# utilisasi_6bulan                       0.025784
# limit_kredit                           0.025377
# kode_cabang_A                          0.025255
# utilisasi_3bulan                       0.024232
# jumlah_tahun_sejak_pembukaan_kredit    0.023518
# total_pemakaian_tunai                  0.022480
# X                                      0.022180
# kode_cabang_B                          0.022015
# kode_cabang_I                          0.021951
# kode_cabang_C                          0.021374
# jumlah_kartu                           0.021099
# total_pemakaian                        0.017511
# kode_cabang_G                          0.017370
# kode_cabang_J                          0.015795
# kode_cabang_K                          0.014660
# kode_cabang_H                          0.010934
# kode_cabang_D                          0.010841
# skor_delikuensi                        0.000000

# %% [markdown]
# membuat plot dari importances

# %%
feature_importances.plot(kind='barh', figsize=(12, 8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest_model = RandomForestClassifier(random_state=70,max_depth=40,n_estimators=55)
forest_model.fit(X_train,y_train)
pred_cv_forest=forest_model.predict(X_test)
score_forest = accuracy_score(pred_cv_forest,y_test)*100
print("akurasi:",score_forest)
print(classification_report(y_test, pred_cv_forest))
# Out:
# akurasi: 91.41658599548241
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      2821
#            1       0.64      0.10      0.17       278
#
#     accuracy                           0.91      3099
#    macro avg       0.78      0.55      0.56      3099
# weighted avg       0.89      0.91      0.88      3099

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8444d434-c952-465d-b031-2cd7b64c6889' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
